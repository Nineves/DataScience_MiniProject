# %%
import requests
import random
import pandas as pd

# %%
api_key = "8157e281df838b043d9cad85cd2542d6";

# %%
random.seed(1)
randomList = random.sample(range(1, 20000),5000)
print(randomList)
# Out:
# [4403, 18652, 2068, 8359, 3864, 16235, 14729, 15475, 12440, 6880, 3076, 15987, 929, 12774, 14181, 19905, 70, 14595, 8728, 7497, 19371, 3350, 10402, 1003, 732, 834, 17742, 302, 12492, 7098, 13832, 952, 17290, 7265, 14349, 16247, 18117, 7638, 11328, 7566, 7170, 15061, 9496, 705, 13638, 18234, 3277, 6092, 9713, 3962, 10902, 16411, 16637, 6221, 9941, 9312, 19254, 16364, 16558, 12890, 19301, 1132, 15737, 7955, 13248, 13577, 5670, 12030, 17984, 12279, 2834, 14384, 16661, 3537, 5365, 17071, 12887, 12142, 16047, 970, 15379, 1425, 10110, 19438, 18946, 12898, 5583, 5525, 16458, 7437, 404, 6538, 17683, 17968, 7608, 13254, 16836, 11267, 18934, 11577, 15045, 8824, 17957, 19954, 188, 12573, 16794, 4236, 16997, 18395, 6734, 13963, 1840, 15765, 11952, 18678, 18167, 6549, 16539, 13547, 15891, 11692, 13580, 11341, 52, 17645, 17699, 10851, 15013, 19657, 917, 7524, 5807, 18048, 19152, 5924, 3002, 18057, 8366, 1064, 2309, 2728, 547, 14844, 478, 9215, 8178, 8803, 3588, 6050, 11287, 9513, 2278, 5488, 5231,
# ...

# %%
movie=requests.get('https://api.themoviedb.org/3/movie/455236?api_key=%s'%api_key)
data=movie.json()
movieList=[key for key in data]
movieList
# Out:
# ['adult',
#  'backdrop_path',
#  'belongs_to_collection',
#  'budget',
#  'genres',
#  'homepage',
#  'id',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'video',
#  'vote_average',
#  'vote_count']

# %%
for i in randomList:
    movieData=requests.get('https://api.themoviedb.org/3/movie/%s?api_key=8157e281df838b043d9cad85cd2542d6'%i)
    moviedata=movieData.json()
    print(moviedata)
    movieList=movieList.append(moviedata,ignore_index=True)
# Out:
# {'adult': False, 'backdrop_path': None, 'belongs_to_collection': None, 'budget': 0, 'genres': [{'id': 18, 'name': 'Drama'}], 'homepage': '', 'id': 4403, 'imdb_id': 'tt0472109', 'original_language': 'en', 'original_title': 'Crossed', 'overview': "A conflicted young man is released from prison after doing time for a crime he didn't commit. However, his attempt at a fresh start goes horribly wrong as he plots his revenge having discovered his best friend is secretly seeing his ex-girlfriend who he's still in love with.", 'popularity': 5.332, 'poster_path': '/l7YxhVQFSvdKOujJ3UqDZxc32RD.jpg', 'production_companies': [], 'production_countries': [{'iso_3166_1': 'CA', 'name': 'Canada'}], 'release_date': '2006-10-09', 'revenue': 0, 'runtime': 83, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': '', 'title': 'Crossed', 'video': False, 'vote_average': 0.0, 'vote_count': 0}
# ...

# %%
movieList

# %%
movieList['genre_ids']=movieList['genre_ids'].astype(str)
movieList.drop_duplicates(inplace=True)
movieList.duplicated().value_counts()     #remove duplicated rows

# %%
movieList['release_date'] = pd.to_datetime(movieList['release_date'])
movieList

# %%
keyword=requests.get('https://api.themoviedb.org/3/keyword/18652?api_key=8157e281df838b043d9cad85cd2542d6')

# %%
kw=keyword.json()

# %%
kw
# Out:
# {'success': False,
#  'status_code': 34,
#  'status_message': 'The resource you requested could not be found.'}

# %%
movie=requests.get('https://api.themoviedb.org/3/movie/455236?api_key=8157e281df838b043d9cad85cd2542d6')

# %%
data=movie.json()

# %%
data
